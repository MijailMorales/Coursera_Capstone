# %% [markdown]
# # Coursera Capstone Project on Datascience
#
# **This not book was created to be use on the Capstone Project.**
#
# All my peers are welcome, and I wish you Success with your own project
#
# ![descarga.jfif](attachment:descarga.jfif)

# %%
import pandas as pd
import numpy as np
print ('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
